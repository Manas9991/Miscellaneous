# %% [markdown]
# <a href="https://colab.research.google.com/github/Manas9991/Miscellaneous/blob/main/HE_Water_Consumption_Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importing Libraries:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from keras import metrics

# %%
dfr = pd.read_csv(r'train.csv')
dfs = pd.read_csv(r'test.csv')

# %%
submission_dfs = dfs.copy()

# %% [markdown]
# ## Cleaning Data

# %%
dfr.head(10)
# Out:
#        Timestamp  Residents Apartment_Type  Temperature Humidity  Water_Price  \
# 0  01/01/2002 00          1         Studio        15.31    46.61         1.06
# 1  01/01/2002 08          4            NaN        21.01    66.11         2.98
# 2  01/01/2002 16          2        Cottage        12.86    60.86         1.44
# 3  02/01/2002 00          2           1BHK        20.16    50.58         1.48
# 4  02/01/2002 08          2        Cottage        16.23    52.25         1.14
# 5  02/01/2002 16          4           2BHK        22.23    53.86         1.15
# 6  03/01/2002 00          3           2BHK        10.83    57.51         2.98
# 7  03/01/2002 08          3        Cottage        30.37    33.88         1.35
# 8  03/01/2002 16          4       Bungalow        16.57    57.94         2.84
# 9  04/01/2002 00          2            NaN        22.59    57.25         1.11
#
#    Period_Consumption_Index  Income_Level  Guests      Amenities  \
# 0                      0.97           Low       0  Swimming Pool
# 1                      0.91  Upper Middle       1  Swimming Pool
# 2                      1.43        Middle       0            NaN
# 3                      0.91        Middle      -1         Garden
# 4                      1.11        Middle       0       Fountain
# 5                      1.46        Middle       0            NaN
# 6                      1.07  Upper Middle       0  Swimming Pool
# 7                      1.40         yePea       0       Fountain
# 8                      1.47  Upper Middle       0         Garden
# 9                      0.99           Low       1            NaN
#
#    Appliance_Usage  Water_Consumption
# 0              0.0              64.85
# 1              1.0             192.50
# 2              1.0             116.62
# 3              0.0              76.96
# 4              0.0             104.70
# 5              1.0             218.23
# 6              0.0             135.80
# 7              0.0             202.29
# 8              0.0             188.04
# 9              1.0              88.94

# %%
# prompt: convert Humidity to decimal, it is stored as object, using to_numeric from pandas

dfr['Humidity'] = pd.to_numeric(dfr['Humidity'], errors='coerce')
dfs['Humidity'] = pd.to_numeric(dfs['Humidity'], errors='coerce')

dfr['Residents'] = pd.to_numeric(dfr['Residents'], errors='coerce')
dfs['Residents'] = pd.to_numeric(dfs['Residents'], errors='coerce')

# %%
dfr['Amenities'] = dfr['Amenities'].fillna('NULL')
dfs['Amenities'] = dfs['Amenities'].fillna('NULL')

dfr['Appliance_Usage'] = dfr['Appliance_Usage'].fillna(0)
dfs['Appliance_Usage'] = dfs['Appliance_Usage'].fillna(0) #dfr['Appliance_Usage'].mean()

# %%
# wherever income level is other than 'Rich', 'Upper Middle', 'Middle', or 'Low', replace it with null values

income_levels = ['Rich', 'Upper Middle', 'Middle', 'Low']
dfr.loc[~dfr['Income_Level'].isin(income_levels), 'Income_Level'] = np.nan
dfs.loc[~dfs['Income_Level'].isin(income_levels), 'Income_Level'] = np.nan

# %%
# replace outliers of humidity with nan

# Calculate Q1, Q3, and IQR for Humidity
Q1 = dfr['Humidity'].quantile(0.1)
Q3 = dfr['Humidity'].quantile(0.9)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Replace outliers with NaN
dfr.loc[(dfr['Humidity'] < lower_bound) | (dfr['Humidity'] > upper_bound), 'Humidity'] = np.nan
dfs.loc[(dfs['Humidity'] < lower_bound) | (dfs['Humidity'] > upper_bound), 'Humidity'] = np.nan

# %%
# prompt: if residents is below 0, make it nan

# Replace Residents values below 0 with NaN
dfr.loc[dfr['Residents'] < 0, 'Residents'] = np.nan
dfs.loc[dfs['Residents'] < 0, 'Residents'] = np.nan

# %%
dfr.loc[dfr['Water_Price'] < 0, 'Water_Price'] = np.nan
dfs.loc[dfs['Water_Price'] < 0, 'Water_Price'] = np.nan

# %%
# Create copies with selected columns
dfr_subset = dfr[['Temperature', 'Water_Price', 'Humidity']].copy()
dfs_subset = dfs[['Temperature', 'Water_Price', 'Humidity']].copy()


# Split into train and test sets based on humidity null values
train_df = dfr_subset.dropna(subset=['Humidity'])
test_df = dfr_subset[dfr_subset['Humidity'].isnull()]
dfs_test = dfs_subset[dfs_subset['Humidity'].isnull()]


# Separate features (X) and target (y) for training
X_train = train_df[['Temperature', 'Water_Price']]
y_train = train_df['Humidity']

X_train['Temperature'] = X_train['Temperature'].fillna(X_train['Temperature'].median())
X_train['Water_Price'] = X_train['Water_Price'].fillna(X_train['Water_Price'].median())

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict humidity for the test set
X_test = test_df[['Temperature', 'Water_Price']]
X_test['Temperature'] = X_test['Temperature'].fillna(X_test['Temperature'].median())
X_test['Water_Price'] = X_test['Water_Price'].fillna(X_test['Water_Price'].median())
predicted_humidity = model.predict(X_test)

# Replace null humidity values in the original dataframe with predictions
dfr.loc[dfr['Humidity'].isnull(), 'Humidity'] = predicted_humidity

# Predict humidity for the test set from the other dataframe
X_test_other = dfs_test[['Temperature', 'Water_Price']]
X_test_other['Temperature'] = X_test_other['Temperature'].fillna(X_test_other['Temperature'].median())
X_test_other['Water_Price'] = X_test_other['Water_Price'].fillna(X_test_other['Water_Price'].median())
predicted_humidity_other = model.predict(X_test_other)

# Replace null humidity values in the original dataframe with predictions
dfs.loc[dfs['Humidity'].isnull(), 'Humidity'] = predicted_humidity_other
# Out:
# <ipython-input-11-33d393db8ef8>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Temperature'] = X_train['Temperature'].fillna(X_train['Temperature'].median())
# <ipython-input-11-33d393db8ef8>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Water_Price'] = X_train['Water_Price'].fillna(X_train['Water_Price'].median())
# <ipython-input-11-33d393db8ef8>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Temperature'] = X_test['Temperature'].fillna(X_test['Temperature'].median())
# <ipython-input-11-33d393db8ef8>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Water_Price'] = X_test['Water_Price'].fillna(X_test['Water_Price'].median())
# <ipython-input-11-33d393db8ef8>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_other['Temperature'] = X_test_other['Temperature'].fillna(X_test_other['Temperature'].median())
# <ipython-input-11-33d393db8ef8>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_other['Water_Price'] = X_test_other['Water_Price'].fillna(X_test_other['Water_Price'].median())

# %%
# Create copies with selected columns
dfr_subset = dfr[['Humidity', 'Temperature']].copy()  # Note the order of columns
dfs_subset = dfs[['Humidity', 'Temperature']].copy()

# Split into train and test sets based on temperature null values
train_df = dfr_subset.dropna(subset=['Temperature'])
test_df = dfr_subset[dfr_subset['Temperature'].isnull()]
dfs_test = dfs_subset[dfs_subset['Temperature'].isnull()]

# Separate features (X) and target (y) for training
X_train = train_df[['Humidity']]
y_train = train_df['Temperature']

X_train['Humidity'] = X_train['Humidity'].fillna(X_train['Humidity'].median())

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict temperature for the test set
X_test = test_df[['Humidity']]
X_test['Humidity'] = X_test['Humidity'].fillna(X_test['Humidity'].median())
predicted_temperature = model.predict(X_test)

# Replace null temperature values in the original dataframe with predictions
dfr.loc[dfr['Temperature'].isnull(), 'Temperature'] = predicted_temperature

# Predict temperature for the test set from the other dataframe
X_test_other = dfs_test[['Humidity']]
X_test_other['Humidity'] = X_test_other['Humidity'].fillna(X_test_other['Humidity'].median())
predicted_temperature_other = model.predict(X_test_other)

# Replace null temperature values in the original dataframe with predictions
dfs.loc[dfs['Temperature'].isnull(), 'Temperature'] = predicted_temperature_other
# Out:
# <ipython-input-12-6205f51cf9bb>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['Humidity'] = X_train['Humidity'].fillna(X_train['Humidity'].median())
# <ipython-input-12-6205f51cf9bb>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['Humidity'] = X_test['Humidity'].fillna(X_test['Humidity'].median())
# <ipython-input-12-6205f51cf9bb>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_other['Humidity'] = X_test_other['Humidity'].fillna(X_test_other['Humidity'].median())

# %%
# Create copies with selected columns
dfr_subset = dfr[['Residents', 'Apartment_Type', 'Water_Price']].copy()
dfs_subset = dfs[['Residents', 'Apartment_Type', 'Water_Price']].copy()

# Impute missing values
dfr_subset['Apartment_Type'] = dfr_subset['Apartment_Type'].fillna(dfr_subset['Apartment_Type'].mode()[0])
dfr_subset['Water_Price'] = dfr_subset['Water_Price'].fillna(dfr_subset['Water_Price'].median())
dfs_subset['Apartment_Type'] = dfs_subset['Apartment_Type'].fillna(dfs_subset['Apartment_Type'].mode()[0])
dfs_subset['Water_Price'] = dfs_subset['Water_Price'].fillna(dfs_subset['Water_Price'].median())

# Convert Apartment_Type to numerical representation
# Create a mapping from apartment types to numbers
apartment_mapping = {apartment_type: i for i, apartment_type in enumerate(dfr_subset['Apartment_Type'].unique())}
dfr_subset['Apartment_Type'] = dfr_subset['Apartment_Type'].map(apartment_mapping)
dfs_subset['Apartment_Type'] = dfs_subset['Apartment_Type'].map(apartment_mapping)

# Handle potential NaN values in the mapping (if any new apartment types exist in test)
dfs_subset['Apartment_Type'] = dfs_subset['Apartment_Type'].fillna(dfs_subset['Apartment_Type'].median())


# Split into train and test sets based on Residents null values
train_df = dfr_subset.dropna(subset=['Residents'])
test_df = dfr_subset[dfr_subset['Residents'].isnull()]
dfs_test = dfs_subset[dfs_subset['Residents'].isnull()]

# Separate features (X) and target (y) for training
X_train = train_df[['Apartment_Type', 'Water_Price']]
y_train = train_df['Residents']

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict Residents for the test set
X_test = test_df[['Apartment_Type', 'Water_Price']]
predicted_residents = model.predict(X_test)

# Replace null Residents values in the original dataframe with predictions
dfr.loc[dfr['Residents'].isnull(), 'Residents'] = predicted_residents

# Predict Residents for the test set from the other dataframe
X_test_other = dfs_test[['Apartment_Type', 'Water_Price']]
predicted_residents_other = model.predict(X_test_other)

# Replace null Residents values in the original dataframe with predictions
dfs.loc[dfs['Residents'].isnull(), 'Residents'] = predicted_residents_other

# %%
# Create copies with selected columns
dfr_subset = dfr[['Water_Price', 'Temperature', 'Apartment_Type', 'Humidity']].copy()
dfs_subset = dfs[['Water_Price', 'Temperature', 'Apartment_Type', 'Humidity']].copy()

# Impute missing values
dfr_subset['Apartment_Type'] = dfr_subset['Apartment_Type'].fillna(dfr_subset['Apartment_Type'].mode()[0])
dfr_subset['Humidity'] = dfr_subset['Humidity'].fillna(dfr_subset['Humidity'].median())
dfs_subset['Apartment_Type'] = dfs_subset['Apartment_Type'].fillna(dfs_subset['Apartment_Type'].mode()[0])
dfs_subset['Humidity'] = dfs_subset['Humidity'].fillna(dfs_subset['Humidity'].median())


# Convert Apartment_Type to numerical representation
# Create a mapping from apartment types to numbers
apartment_mapping = {apartment_type: i for i, apartment_type in enumerate(dfr_subset['Apartment_Type'].unique())}
dfr_subset['Apartment_Type'] = dfr_subset['Apartment_Type'].map(apartment_mapping)
dfs_subset['Apartment_Type'] = dfs_subset['Apartment_Type'].map(apartment_mapping)

# Handle potential NaN values in the mapping (if any new apartment types exist in test)
dfs_subset['Apartment_Type'] = dfs_subset['Apartment_Type'].fillna(dfs_subset['Apartment_Type'].median())


# Split into train and test sets based on Water_Price null values
train_df = dfr_subset.dropna(subset=['Water_Price'])
test_df = dfr_subset[dfr_subset['Water_Price'].isnull()]
dfs_test = dfs_subset[dfs_subset['Water_Price'].isnull()]

# Separate features (X) and target (y) for training
X_train = train_df[['Temperature', 'Apartment_Type', 'Humidity']]
y_train = train_df['Water_Price']

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict Water_Price for the test set
X_test = test_df[['Temperature', 'Apartment_Type', 'Humidity']]
predicted_water_price = model.predict(X_test)

# Replace null Water_Price values in the original dataframe with predictions
dfr.loc[dfr['Water_Price'].isnull(), 'Water_Price'] = predicted_water_price

# Predict Water_Price for the test set from the other dataframe
X_test_other = dfs_test[['Temperature', 'Apartment_Type', 'Humidity']]
predicted_water_price_other = model.predict(X_test_other)

# Replace null Water_Price values in the original dataframe with predictions
dfs.loc[dfs['Water_Price'].isnull(), 'Water_Price'] = predicted_water_price_other

# %%
# prompt: create a dataframe containing income levels and corresponding highest frequency apartment types. Also print the frequency

# Group by income level and apartment type, count occurrences
income_apartment_counts = dfr.groupby(['Income_Level', 'Apartment_Type']).size().reset_index(name='counts')

# Find the most frequent apartment type for each income level
income_apartment_max = income_apartment_counts.loc[income_apartment_counts.groupby('Income_Level')['counts'].idxmax()]

# Create the DataFrame
income_apartment_df = pd.DataFrame({'Income_Level': income_apartment_max['Income_Level'],
                                   'Most Frequent Apartment': income_apartment_max['Apartment_Type'],
                                   'Frequency': income_apartment_max['counts']})

# Print the DataFrame
income_apartment_df
# Out:
#     Income_Level Most Frequent Apartment  Frequency
# 1            Low                  Studio       1125
# 2         Middle                    1BHK       1734
# 5           Rich                    3BHK        518
# 10  Upper Middle                Bungalow       1297

# %%
# prompt: create a dataframe containing residents (rounded and converted to integer) and corresponding highest frequency apartment types. Also print the frequency

# Round and convert 'Residents' to integers
dfr['Residents'] = dfr['Residents'].round().astype(int)

# Group by 'Residents' and 'Apartment_Type', count occurrences
resident_apartment_counts = dfr.groupby(['Residents', 'Apartment_Type']).size().reset_index(name='counts')

# Find the most frequent apartment type for each resident count
resident_apartment_max = resident_apartment_counts.loc[resident_apartment_counts.groupby('Residents')['counts'].idxmax()]

# Create the DataFrame
resident_apartment_df = pd.DataFrame({
    'Residents': resident_apartment_max['Residents'],
    'Most Frequent Apartment': resident_apartment_max['Apartment_Type'],
    'Frequency': resident_apartment_max['counts']
})

# Print the DataFrame and frequency
resident_apartment_df
# Out:
#     Residents Most Frequent Apartment  Frequency
# 0           1                  Studio        590
# 1           2                    1BHK       1529
# 5           3                    1BHK       1490
# 12          4                    2BHK        999
# 16          5                    2BHK       1029

# %%
# prompt: replace missing apartment type values so that they are mapped to the dataframe income_apartment_df.

# Replace missing 'Apartment_Type' values based on 'Income_Level'
def replace_missing_apartment_type(row):
    if pd.isnull(row['Apartment_Type']):
        income_level = row['Income_Level']
        if income_level in income_apartment_df['Income_Level'].values:
            return income_apartment_df[income_apartment_df['Income_Level'] == income_level]['Most Frequent Apartment'].iloc[0]
        else:
            return '1BHK'
    return row['Apartment_Type']

dfr['Apartment_Type'] = dfr.apply(replace_missing_apartment_type, axis=1)
dfs['Apartment_Type'] = dfs.apply(replace_missing_apartment_type, axis=1)

# %%
# Group by apartment type and income level, count occurrences
apartment_income_counts = dfr.groupby(['Apartment_Type', 'Income_Level']).size().reset_index(name='counts')

# Find the most frequent income level for each apartment type
apartment_income_max = apartment_income_counts.loc[apartment_income_counts.groupby('Apartment_Type')['counts'].idxmax()]

# Create the DataFrame
apartment_income_df = pd.DataFrame({
    'Apartment_Type': apartment_income_max['Apartment_Type'],
    'Most Frequent Income': apartment_income_max['Income_Level'],
    'Frequency': apartment_income_max['counts']
})

# Print the DataFrame
apartment_income_df
# Out:
#    Apartment_Type Most Frequent Income  Frequency
# 1            1BHK               Middle       1922
# 2            2BHK               Middle       1675
# 5            3BHK         Upper Middle       1275
# 7        Bungalow         Upper Middle       1402
# 8         Cottage               Middle       1726
# 9        Detached                 Rich        517
# 10         Studio                  Low       1193

# %%
# prompt: replace missing income level values so that they are mapped to the dataframe apartment_income_df. If apartment type is null, return text 'NULL'

# Replace missing 'Income_Level' values based on 'Apartment_Type'
def replace_missing_income_level(row):
    if pd.isnull(row['Income_Level']):
        apartment_type = row['Apartment_Type']
        if apartment_type in apartment_income_df['Apartment_Type'].values:
            return apartment_income_df[apartment_income_df['Apartment_Type'] == apartment_type]['Most Frequent Income'].iloc[0]
        else:
            return 'Middle'  # Or another appropriate default value
    return row['Income_Level']

dfr['Income_Level'] = dfr.apply(replace_missing_income_level, axis=1)
dfs['Income_Level'] = dfs.apply(replace_missing_income_level, axis=1)

# %%
# prompt: convert Apartment type and income level to one hot encoded variables, and remove the original columns. Before doing that, replace everything that's not 'Rich', 'Upper Middle', 'Middle', 'Low', or 'NULL' with 'Others' in income level. Same for apartment type, use the top 6 frequently occurring apartment types and 'NULL' and replace the rest with Others. In one hot encoding, do not convert to True and False, make it numeric 1 and 0. Do the same for Amenities variable also, take all values including 'NULL'

# One-hot encode 'Income_Level', 'Apartment_Type', and 'Amenities'
def one_hot_encode(df, column_name):
    dummies = pd.get_dummies(df[column_name], prefix=column_name, drop_first=False)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column_name, axis=1)
    return df

for col in ['Income_Level', 'Apartment_Type', 'Amenities']:
    dfr = one_hot_encode(dfr, col)
    dfs = one_hot_encode(dfs, col)

# %%
dfr.drop(columns = ['Timestamp'], inplace = True)
dfs.drop(columns = ['Timestamp'], inplace = True)

# %%
dfr['Total_Occupants'] = dfr['Residents'] + dfr['Guests']
dfs['Total_Occupants'] = dfs['Residents'] + dfs['Guests']

# %%
# Ceil and floor outliers for Humidity
def cap_outliers(df, column, lower_percentile=0.1, upper_percentile=0.9):
    lower_bound = df[column].quantile(lower_percentile)
    upper_bound = df[column].quantile(upper_percentile)
    df[column] = np.clip(df[column], lower_bound, upper_bound)
    return df

dfr = cap_outliers(dfr, 'Guests', 0.02, 0.95)
dfs = cap_outliers(dfs, 'Guests', 0.02, 0.95)

dfr = cap_outliers(dfr, 'Period_Consumption_Index', 0.005, 0.99)
dfs = cap_outliers(dfs, 'Period_Consumption_Index', 0.005, 0.99)

# %%
# Feature Engineering

dfr['Temp_Humidity_Interaction'] = dfr['Temperature'] * dfr['Humidity']
dfs['Temp_Humidity_Interaction'] = dfs['Temperature'] * dfs['Humidity']

# %%
# prompt: convert all dfr and dfs columns to_numeric if they aren't already

# Convert columns to numeric, handling errors
for col in dfr.columns:
    if not pd.api.types.is_numeric_dtype(dfr[col]):
        dfr[col] = pd.to_numeric(dfr[col], errors='coerce')

for col in dfs.columns:
    if not pd.api.types.is_numeric_dtype(dfs[col]):
        dfs[col] = pd.to_numeric(dfs[col], errors='coerce')

# %%
dfr['Period_Consumption_Index'].describe()
# Out:
# count    14000.000000
# mean         1.151297
# std          0.219886
# min          0.392344
# 25%          0.970000
# 50%          1.150000
# 75%          1.330000
# max          1.645256
# Name: Period_Consumption_Index, dtype: float64

# %%
dfr.head()
# Out:
#    Residents  Temperature  Humidity  Water_Price  Period_Consumption_Index  \
# 0          1        15.31     46.61         1.06                      0.97
# 1          4        21.01     66.11         2.98                      0.91
# 2          2        12.86     60.86         1.44                      1.43
# 3          2        20.16     50.58         1.48                      0.91
# 4          2        16.23     52.25         1.14                      1.11
#
#    Guests  Appliance_Usage  Water_Consumption  Income_Level_Low  \
# 0       0              0.0              64.85              True
# 1       1              1.0             192.50             False
# 2       0              1.0             116.62             False
# 3       0              0.0              76.96             False
# 4       0              0.0             104.70             False
#
#    Income_Level_Middle  ...  Apartment_Type_Cottage  Apartment_Type_Detached  \
# 0                False  ...                   False                    False
# 1                False  ...                   False                    False
# 2                 True  ...                    True                    False
# 3                 True  ...                   False                    False
# 4                 True  ...                    True                    False
#
#    Apartment_Type_Studio  Amenities_Fountain  Amenities_Garden  \
# 0                   True               False             False
# 1                  False               False             False
# 2                  False               False             False
# 3                  False               False              True
# 4                  False                True             False
#
#    Amenities_Jacuzzi  Amenities_NULL  Amenities_Swimming Pool  \
# 0              False           False                     True
# 1              False           False                     True
# 2              False            True                    False
# 3              False           False                    False
# 4              False           False                    False
#
#    Total_Occupants  Temp_Humidity_Interaction
# 0                1                   713.5991
# 1                5                  1388.9711
# 2                2                   782.6596
# 3                1                  1019.6928
# 4                2                   848.0175
#
# [5 rows x 26 columns]

# %% [markdown]
# ##Applying ML Models:

# %%
x = dfr.drop(columns=['Water_Consumption'])
y = dfr['Water_Consumption']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size = 0.99995)

# %%
feature_names = dfs.columns

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
dfs = scaler.fit_transform(dfs)

# %%
# Define the model
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu6', input_shape=(X_train.shape[1],)),
    keras.layers.Dense(64, activation='relu6'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1)  # Output layer for regression
])

# Compile the model
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=1000,
    decay_rate=0.85)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(optimizer=opt, loss='mse', metrics=[metrics.MeanSquaredError()])

# Train the model
history = model.fit(X_train, y_train, epochs=300, batch_size=64, validation_split=0.2, verbose=1)

# Evaluate the model
y_pred = model.predict(X_test)
train_mae = mean_absolute_error(y_train, model.predict(X_train))
test_mae = mean_absolute_error(y_test, y_pred)

# Evaluate the model
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Mean Absolute Error on Test Data: {mae}")
y_pred = model.predict(X_test)
print("Train RMSE: ", np.sqrt(mean_squared_error(y_train, model.predict(X_train))))
print("Test RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - loss: 22137.3066 - mean_squared_error: 22137.3066 - val_loss: 1383.0845 - val_mean_squared_error: 1383.0845
# Epoch 2/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 962.0498 - mean_squared_error: 962.0498 - val_loss: 500.6865 - val_mean_squared_error: 500.6865
# Epoch 3/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 416.4462 - mean_squared_error: 416.4462 - val_loss: 336.4789 - val_mean_squared_error: 336.4789
# Epoch 4/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 306.1096 - mean_squared_error: 306.1096 - val_loss: 281.4936 - val_mean_squared_error: 281.4936
# Epoch 5/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 267.9052 - mean_squared_error: 267.9052 - val_loss: 277.3311 - val_mean_squared_error: 277.3311
# Epoch 6/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 240.8689 - mean_squared_error: 240.8689 - val_loss: 250.0665 - val_mean_squared_error: 250.0665
# Epoch 7/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 239.8553 - mean_squared_error: 239.8553 - val_loss: 243.6119 - val_mean_squared_error: 243.6119
# Epoch 8/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 216.9130 - mean_squared_error: 216.9130 - val_loss: 234.9735 - val_mean_squared_error: 234.9735
# Epoch 9/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 229.4287 - mean_squared_error: 229.4287 - val_loss: 233.8084 - val_mean_squared_error: 233.8084
# Epoch 10/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 207.5878 - mean_squared_error: 207.5878 - val_loss: 240.3325 - val_mean_squared_error: 240.3325
# Epoch 11/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 230.6027 - mean_squared_error: 230.6027 - val_loss: 224.2675 - val_mean_squared_error: 224.2675
# Epoch 12/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 211.6602 - mean_squared_error: 211.6602 - val_loss: 229.4092 - val_mean_squared_error: 229.4092
# Epoch 13/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 211.1995 - mean_squared_error: 211.1995 - val_loss: 216.4154 - val_mean_squared_error: 216.4154
# Epoch 14/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 216.3251 - mean_squared_error: 216.3251 - val_loss: 214.2498 - val_mean_squared_error: 214.2498
# Epoch 15/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 194.0215 - mean_squared_error: 194.0215 - val_loss: 206.9300 - val_mean_squared_error: 206.9300
# Epoch 16/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 203.0882 - mean_squared_error: 203.0882 - val_loss: 206.2451 - val_mean_squared_error: 206.2451
# Epoch 17/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 195.1889 - mean_squared_error: 195.1889 - val_loss: 194.2106 - val_mean_squared_error: 194.2106
# Epoch 18/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 184.5068 - mean_squared_error: 184.5068 - val_loss: 184.0826 - val_mean_squared_error: 184.0826
# Epoch 19/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 182.2967 - mean_squared_error: 182.2967 - val_loss: 183.7119 - val_mean_squared_error: 183.7119
# Epoch 20/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 178.9830 - mean_squared_error: 178.9830 - val_loss: 175.5301 - val_mean_squared_error: 175.5301
# Epoch 21/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 162.0785 - mean_squared_error: 162.0785 - val_loss: 175.1822 - val_mean_squared_error: 175.1822
# Epoch 22/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 169.1579 - mean_squared_error: 169.1579 - val_loss: 167.5909 - val_mean_squared_error: 167.5909
# Epoch 23/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 136.6739 - mean_squared_error: 136.6739 - val_loss: 165.7606 - val_mean_squared_error: 165.7606
# Epoch 24/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 156.0056 - mean_squared_error: 156.0056 - val_loss: 161.2457 - val_mean_squared_error: 161.2457
# Epoch 25/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 138.5449 - mean_squared_error: 138.5449 - val_loss: 159.3417 - val_mean_squared_error: 159.3417
# Epoch 26/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 136.3157 - mean_squared_error: 136.3157 - val_loss: 158.5646 - val_mean_squared_error: 158.5646
# Epoch 27/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 135.1869 - mean_squared_error: 135.1869 - val_loss: 155.3373 - val_mean_squared_error: 155.3373
# Epoch 28/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 138.3105 - mean_squared_error: 138.3105 - val_loss: 158.0028 - val_mean_squared_error: 158.0028
# Epoch 29/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 142.9089 - mean_squared_error: 142.9089 - val_loss: 154.5174 - val_mean_squared_error: 154.5174
# Epoch 30/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 136.2697 - mean_squared_error: 136.2697 - val_loss: 149.6152 - val_mean_squared_error: 149.6152
# Epoch 31/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 132.4964 - mean_squared_error: 132.4964 - val_loss: 147.7942 - val_mean_squared_error: 147.7942
# Epoch 32/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 133.6116 - mean_squared_error: 133.6116 - val_loss: 146.5030 - val_mean_squared_error: 146.5030
# Epoch 33/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 121.7305 - mean_squared_error: 121.7305 - val_loss: 144.2890 - val_mean_squared_error: 144.2890
# Epoch 34/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 128.7472 - mean_squared_error: 128.7472 - val_loss: 143.3253 - val_mean_squared_error: 143.3253
# Epoch 35/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 129.0463 - mean_squared_error: 129.0463 - val_loss: 149.2084 - val_mean_squared_error: 149.2084
# Epoch 36/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 123.2834 - mean_squared_error: 123.2834 - val_loss: 152.7272 - val_mean_squared_error: 152.7272
# Epoch 37/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 123.8276 - mean_squared_error: 123.8276 - val_loss: 142.0508 - val_mean_squared_error: 142.0508
# Epoch 38/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 136.6334 - mean_squared_error: 136.6334 - val_loss: 141.9488 - val_mean_squared_error: 141.9488
# Epoch 39/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 125.0644 - mean_squared_error: 125.0644 - val_loss: 140.0814 - val_mean_squared_error: 140.0814
# Epoch 40/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 123.6847 - mean_squared_error: 123.6847 - val_loss: 143.4417 - val_mean_squared_error: 143.4417
# Epoch 41/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 110.4594 - mean_squared_error: 110.4594 - val_loss: 140.9530 - val_mean_squared_error: 140.9530
# Epoch 42/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 119.6586 - mean_squared_error: 119.6586 - val_loss: 137.5827 - val_mean_squared_error: 137.5827
# Epoch 43/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 127.2420 - mean_squared_error: 127.2420 - val_loss: 136.9321 - val_mean_squared_error: 136.9321
# Epoch 44/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 114.5892 - mean_squared_error: 114.5892 - val_loss: 136.3876 - val_mean_squared_error: 136.3876
# Epoch 45/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 129.0401 - mean_squared_error: 129.0401 - val_loss: 136.4667 - val_mean_squared_error: 136.4667
# Epoch 46/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 113.1021 - mean_squared_error: 113.1021 - val_loss: 137.1924 - val_mean_squared_error: 137.1924
# Epoch 47/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 106.9004 - mean_squared_error: 106.9004 - val_loss: 136.3636 - val_mean_squared_error: 136.3636
# Epoch 48/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 94.0802 - mean_squared_error: 94.0802 - val_loss: 135.6718 - val_mean_squared_error: 135.6718
# Epoch 49/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 113.8977 - mean_squared_error: 113.8977 - val_loss: 136.3246 - val_mean_squared_error: 136.3246
# Epoch 50/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 112.1490 - mean_squared_error: 112.1490 - val_loss: 134.8638 - val_mean_squared_error: 134.8638
# Epoch 51/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 108.6860 - mean_squared_error: 108.6860 - val_loss: 137.0972 - val_mean_squared_error: 137.0972
# Epoch 52/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 104.0924 - mean_squared_error: 104.0924 - val_loss: 134.3038 - val_mean_squared_error: 134.3038
# Epoch 53/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 109.8497 - mean_squared_error: 109.8497 - val_loss: 135.4996 - val_mean_squared_error: 135.4996
# Epoch 54/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 108.8210 - mean_squared_error: 108.8210 - val_loss: 133.5352 - val_mean_squared_error: 133.5352
# Epoch 55/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 112.1328 - mean_squared_error: 112.1328 - val_loss: 133.7919 - val_mean_squared_error: 133.7919
# Epoch 56/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 114.2677 - mean_squared_error: 114.2677 - val_loss: 133.5668 - val_mean_squared_error: 133.5668
# Epoch 57/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 107.5109 - mean_squared_error: 107.5109 - val_loss: 132.1453 - val_mean_squared_error: 132.1453
# Epoch 58/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 105.1821 - mean_squared_error: 105.1821 - val_loss: 133.2672 - val_mean_squared_error: 133.2672
# Epoch 59/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.0363 - mean_squared_error: 100.0363 - val_loss: 133.1079 - val_mean_squared_error: 133.1079
# Epoch 60/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 108.9289 - mean_squared_error: 108.9289 - val_loss: 134.1433 - val_mean_squared_error: 134.1433
# Epoch 61/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 118.2763 - mean_squared_error: 118.2763 - val_loss: 132.2588 - val_mean_squared_error: 132.2588
# Epoch 62/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 102.7299 - mean_squared_error: 102.7299 - val_loss: 131.9108 - val_mean_squared_error: 131.9108
# Epoch 63/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 103.1120 - mean_squared_error: 103.1120 - val_loss: 131.4129 - val_mean_squared_error: 131.4129
# Epoch 64/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 110.5071 - mean_squared_error: 110.5071 - val_loss: 131.5692 - val_mean_squared_error: 131.5692
# Epoch 65/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 109.3457 - mean_squared_error: 109.3457 - val_loss: 132.0907 - val_mean_squared_error: 132.0907
# Epoch 66/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 111.9943 - mean_squared_error: 111.9943 - val_loss: 130.4821 - val_mean_squared_error: 130.4821
# Epoch 67/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.6561 - mean_squared_error: 92.6561 - val_loss: 131.4891 - val_mean_squared_error: 131.4891
# Epoch 68/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.0617 - mean_squared_error: 95.0617 - val_loss: 131.2431 - val_mean_squared_error: 131.2431
# Epoch 69/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 106.4900 - mean_squared_error: 106.4900 - val_loss: 132.4274 - val_mean_squared_error: 132.4274
# Epoch 70/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 107.0035 - mean_squared_error: 107.0035 - val_loss: 130.6090 - val_mean_squared_error: 130.6090
# Epoch 71/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.7858 - mean_squared_error: 97.7858 - val_loss: 131.3390 - val_mean_squared_error: 131.3390
# Epoch 72/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 105.6431 - mean_squared_error: 105.6431 - val_loss: 133.0490 - val_mean_squared_error: 133.0490
# Epoch 73/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 106.6324 - mean_squared_error: 106.6324 - val_loss: 131.4256 - val_mean_squared_error: 131.4256
# Epoch 74/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 105.0656 - mean_squared_error: 105.0656 - val_loss: 129.9676 - val_mean_squared_error: 129.9676
# Epoch 75/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.9840 - mean_squared_error: 96.9840 - val_loss: 130.9862 - val_mean_squared_error: 130.9862
# Epoch 76/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 94.3159 - mean_squared_error: 94.3159 - val_loss: 129.8680 - val_mean_squared_error: 129.8680
# Epoch 77/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 104.4540 - mean_squared_error: 104.4540 - val_loss: 129.3115 - val_mean_squared_error: 129.3115
# Epoch 78/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 104.2122 - mean_squared_error: 104.2122 - val_loss: 130.0492 - val_mean_squared_error: 130.0492
# Epoch 79/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.2716 - mean_squared_error: 97.2716 - val_loss: 129.9197 - val_mean_squared_error: 129.9197
# Epoch 80/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 105.2213 - mean_squared_error: 105.2213 - val_loss: 128.8530 - val_mean_squared_error: 128.8530
# Epoch 81/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 104.5327 - mean_squared_error: 104.5327 - val_loss: 129.8131 - val_mean_squared_error: 129.8131
# Epoch 82/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.2105 - mean_squared_error: 96.2105 - val_loss: 130.6278 - val_mean_squared_error: 130.6278
# Epoch 83/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 103.4305 - mean_squared_error: 103.4305 - val_loss: 129.9293 - val_mean_squared_error: 129.9293
# Epoch 84/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 117.9697 - mean_squared_error: 117.9697 - val_loss: 128.6422 - val_mean_squared_error: 128.6422
# Epoch 85/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.7948 - mean_squared_error: 101.7948 - val_loss: 129.9146 - val_mean_squared_error: 129.9146
# Epoch 86/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 108.3427 - mean_squared_error: 108.3427 - val_loss: 129.3604 - val_mean_squared_error: 129.3604
# Epoch 87/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.2552 - mean_squared_error: 91.2552 - val_loss: 129.3142 - val_mean_squared_error: 129.3142
# Epoch 88/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.6240 - mean_squared_error: 101.6240 - val_loss: 129.1467 - val_mean_squared_error: 129.1467
# Epoch 89/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.3606 - mean_squared_error: 102.3606 - val_loss: 129.0649 - val_mean_squared_error: 129.0649
# Epoch 90/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.2948 - mean_squared_error: 90.2948 - val_loss: 128.9306 - val_mean_squared_error: 128.9306
# Epoch 91/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.6763 - mean_squared_error: 98.6763 - val_loss: 129.4527 - val_mean_squared_error: 129.4527
# Epoch 92/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.3843 - mean_squared_error: 93.3843 - val_loss: 129.0517 - val_mean_squared_error: 129.0517
# Epoch 93/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.2018 - mean_squared_error: 101.2018 - val_loss: 129.0129 - val_mean_squared_error: 129.0129
# Epoch 94/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 99.1437 - mean_squared_error: 99.1437 - val_loss: 128.8123 - val_mean_squared_error: 128.8123
# Epoch 95/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 108.2361 - mean_squared_error: 108.2361 - val_loss: 128.9075 - val_mean_squared_error: 128.9075
# Epoch 96/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 99.8458 - mean_squared_error: 99.8458 - val_loss: 128.6398 - val_mean_squared_error: 128.6398
# Epoch 97/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 89.6969 - mean_squared_error: 89.6969 - val_loss: 128.7191 - val_mean_squared_error: 128.7191
# Epoch 98/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.3385 - mean_squared_error: 91.3385 - val_loss: 129.3166 - val_mean_squared_error: 129.3166
# Epoch 99/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 105.3498 - mean_squared_error: 105.3498 - val_loss: 128.5592 - val_mean_squared_error: 128.5592
# Epoch 100/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 96.5931 - mean_squared_error: 96.5931 - val_loss: 128.5719 - val_mean_squared_error: 128.5719
# Epoch 101/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.3697 - mean_squared_error: 97.3697 - val_loss: 129.3131 - val_mean_squared_error: 129.3131
# Epoch 102/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 99.7227 - mean_squared_error: 99.7227 - val_loss: 128.4944 - val_mean_squared_error: 128.4944
# Epoch 103/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 108.2402 - mean_squared_error: 108.2402 - val_loss: 128.2828 - val_mean_squared_error: 128.2828
# Epoch 104/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.1507 - mean_squared_error: 93.1507 - val_loss: 129.0193 - val_mean_squared_error: 129.0193
# Epoch 105/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.2998 - mean_squared_error: 100.2998 - val_loss: 128.2545 - val_mean_squared_error: 128.2545
# Epoch 106/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.6895 - mean_squared_error: 91.6895 - val_loss: 128.3862 - val_mean_squared_error: 128.3862
# Epoch 107/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.9167 - mean_squared_error: 90.9167 - val_loss: 128.2851 - val_mean_squared_error: 128.2851
# Epoch 108/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.3071 - mean_squared_error: 102.3071 - val_loss: 128.6892 - val_mean_squared_error: 128.6892
# Epoch 109/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 101.0158 - mean_squared_error: 101.0158 - val_loss: 128.2500 - val_mean_squared_error: 128.2500
# Epoch 110/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 99.5635 - mean_squared_error: 99.5635 - val_loss: 128.5259 - val_mean_squared_error: 128.5259
# Epoch 111/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94.1205 - mean_squared_error: 94.1205 - val_loss: 128.3375 - val_mean_squared_error: 128.3375
# Epoch 112/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.7371 - mean_squared_error: 100.7371 - val_loss: 128.0865 - val_mean_squared_error: 128.0865
# Epoch 113/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 108.1553 - mean_squared_error: 108.1553 - val_loss: 128.3405 - val_mean_squared_error: 128.3405
# Epoch 114/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.1876 - mean_squared_error: 96.1876 - val_loss: 128.2388 - val_mean_squared_error: 128.2388
# Epoch 115/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.4134 - mean_squared_error: 93.4134 - val_loss: 128.1001 - val_mean_squared_error: 128.1001
# Epoch 116/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 105.0836 - mean_squared_error: 105.0836 - val_loss: 128.0116 - val_mean_squared_error: 128.0116
# Epoch 117/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.6555 - mean_squared_error: 95.6555 - val_loss: 128.0876 - val_mean_squared_error: 128.0876
# Epoch 118/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 93.5015 - mean_squared_error: 93.5015 - val_loss: 127.9588 - val_mean_squared_error: 127.9588
# Epoch 119/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 95.6792 - mean_squared_error: 95.6792 - val_loss: 127.9721 - val_mean_squared_error: 127.9721
# Epoch 120/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 88.0822 - mean_squared_error: 88.0822 - val_loss: 127.8751 - val_mean_squared_error: 127.8751
# Epoch 121/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.3761 - mean_squared_error: 102.3761 - val_loss: 127.8651 - val_mean_squared_error: 127.8651
# Epoch 122/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.3932 - mean_squared_error: 92.3932 - val_loss: 128.6077 - val_mean_squared_error: 128.6077
# Epoch 123/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.7652 - mean_squared_error: 92.7652 - val_loss: 127.9570 - val_mean_squared_error: 127.9570
# Epoch 124/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 106.4085 - mean_squared_error: 106.4085 - val_loss: 128.2476 - val_mean_squared_error: 128.2476
# Epoch 125/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.0524 - mean_squared_error: 90.0524 - val_loss: 127.9124 - val_mean_squared_error: 127.9124
# Epoch 126/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 111.4913 - mean_squared_error: 111.4913 - val_loss: 127.7519 - val_mean_squared_error: 127.7519
# Epoch 127/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.1200 - mean_squared_error: 102.1200 - val_loss: 127.8655 - val_mean_squared_error: 127.8655
# Epoch 128/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 88.5706 - mean_squared_error: 88.5706 - val_loss: 128.1621 - val_mean_squared_error: 128.1621
# Epoch 129/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.2622 - mean_squared_error: 102.2622 - val_loss: 127.7755 - val_mean_squared_error: 127.7755
# Epoch 130/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.5382 - mean_squared_error: 91.5382 - val_loss: 127.8304 - val_mean_squared_error: 127.8304
# Epoch 131/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.9288 - mean_squared_error: 100.9288 - val_loss: 127.7637 - val_mean_squared_error: 127.7637
# Epoch 132/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.4812 - mean_squared_error: 95.4812 - val_loss: 127.8341 - val_mean_squared_error: 127.8341
# Epoch 133/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.0170 - mean_squared_error: 92.0170 - val_loss: 127.8213 - val_mean_squared_error: 127.8213
# Epoch 134/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94.1521 - mean_squared_error: 94.1521 - val_loss: 127.8426 - val_mean_squared_error: 127.8426
# Epoch 135/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.2746 - mean_squared_error: 95.2746 - val_loss: 127.7890 - val_mean_squared_error: 127.7890
# Epoch 136/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 96.7629 - mean_squared_error: 96.7629 - val_loss: 127.7281 - val_mean_squared_error: 127.7281
# Epoch 137/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 92.1387 - mean_squared_error: 92.1387 - val_loss: 127.6494 - val_mean_squared_error: 127.6494
# Epoch 138/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 93.0851 - mean_squared_error: 93.0851 - val_loss: 127.8133 - val_mean_squared_error: 127.8133
# Epoch 139/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 97.4214 - mean_squared_error: 97.4214 - val_loss: 127.6968 - val_mean_squared_error: 127.6968
# Epoch 140/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94.8195 - mean_squared_error: 94.8195 - val_loss: 127.6685 - val_mean_squared_error: 127.6685
# Epoch 141/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.9549 - mean_squared_error: 96.9549 - val_loss: 127.8141 - val_mean_squared_error: 127.8141
# Epoch 142/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.0584 - mean_squared_error: 95.0584 - val_loss: 127.8671 - val_mean_squared_error: 127.8671
# Epoch 143/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.5182 - mean_squared_error: 96.5182 - val_loss: 127.7403 - val_mean_squared_error: 127.7403
# Epoch 144/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.6175 - mean_squared_error: 100.6175 - val_loss: 127.7118 - val_mean_squared_error: 127.7118
# Epoch 145/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.5604 - mean_squared_error: 100.5604 - val_loss: 127.8435 - val_mean_squared_error: 127.8435
# Epoch 146/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.0866 - mean_squared_error: 97.0866 - val_loss: 127.7051 - val_mean_squared_error: 127.7051
# Epoch 147/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 103.2177 - mean_squared_error: 103.2177 - val_loss: 127.7217 - val_mean_squared_error: 127.7217
# Epoch 148/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.8605 - mean_squared_error: 101.8605 - val_loss: 127.7382 - val_mean_squared_error: 127.7382
# Epoch 149/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.5751 - mean_squared_error: 100.5751 - val_loss: 127.6388 - val_mean_squared_error: 127.6388
# Epoch 150/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 105.4888 - mean_squared_error: 105.4888 - val_loss: 127.8747 - val_mean_squared_error: 127.8747
# Epoch 151/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.6118 - mean_squared_error: 97.6118 - val_loss: 127.6650 - val_mean_squared_error: 127.6650
# Epoch 152/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 106.7113 - mean_squared_error: 106.7113 - val_loss: 127.6807 - val_mean_squared_error: 127.6807
# Epoch 153/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.9091 - mean_squared_error: 98.9091 - val_loss: 127.6397 - val_mean_squared_error: 127.6397
# Epoch 154/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 103.5313 - mean_squared_error: 103.5313 - val_loss: 127.6593 - val_mean_squared_error: 127.6593
# Epoch 155/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 97.6381 - mean_squared_error: 97.6381 - val_loss: 127.6858 - val_mean_squared_error: 127.6858
# Epoch 156/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.3574 - mean_squared_error: 102.3574 - val_loss: 127.6725 - val_mean_squared_error: 127.6725
# Epoch 157/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.9859 - mean_squared_error: 93.9859 - val_loss: 127.6664 - val_mean_squared_error: 127.6664
# Epoch 158/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.9940 - mean_squared_error: 93.9940 - val_loss: 127.6875 - val_mean_squared_error: 127.6875
# Epoch 159/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.1289 - mean_squared_error: 96.1289 - val_loss: 127.6336 - val_mean_squared_error: 127.6336
# Epoch 160/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.0268 - mean_squared_error: 100.0268 - val_loss: 127.6258 - val_mean_squared_error: 127.6258
# Epoch 161/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.3341 - mean_squared_error: 96.3341 - val_loss: 127.6592 - val_mean_squared_error: 127.6592
# Epoch 162/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.2887 - mean_squared_error: 90.2887 - val_loss: 127.6677 - val_mean_squared_error: 127.6677
# Epoch 163/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.7425 - mean_squared_error: 98.7425 - val_loss: 127.6632 - val_mean_squared_error: 127.6632
# Epoch 164/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.9616 - mean_squared_error: 91.9616 - val_loss: 127.6349 - val_mean_squared_error: 127.6349
# Epoch 165/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.9484 - mean_squared_error: 96.9484 - val_loss: 127.6366 - val_mean_squared_error: 127.6366
# Epoch 166/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.7128 - mean_squared_error: 98.7128 - val_loss: 127.7026 - val_mean_squared_error: 127.7026
# Epoch 167/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.5120 - mean_squared_error: 97.5120 - val_loss: 127.6246 - val_mean_squared_error: 127.6246
# Epoch 168/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.3759 - mean_squared_error: 91.3759 - val_loss: 127.6213 - val_mean_squared_error: 127.6213
# Epoch 169/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.4411 - mean_squared_error: 102.4411 - val_loss: 127.6528 - val_mean_squared_error: 127.6528
# Epoch 170/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.2534 - mean_squared_error: 92.2534 - val_loss: 127.6349 - val_mean_squared_error: 127.6349
# Epoch 171/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.3193 - mean_squared_error: 95.3193 - val_loss: 127.6909 - val_mean_squared_error: 127.6909
# Epoch 172/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 97.8028 - mean_squared_error: 97.8028 - val_loss: 127.6282 - val_mean_squared_error: 127.6282
# Epoch 173/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 98.0374 - mean_squared_error: 98.0374 - val_loss: 127.6207 - val_mean_squared_error: 127.6207
# Epoch 174/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 86.5426 - mean_squared_error: 86.5426 - val_loss: 127.6371 - val_mean_squared_error: 127.6371
# Epoch 175/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 88.8828 - mean_squared_error: 88.8828 - val_loss: 127.6338 - val_mean_squared_error: 127.6338
# Epoch 176/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.0783 - mean_squared_error: 98.0783 - val_loss: 127.6536 - val_mean_squared_error: 127.6536
# Epoch 177/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94.5169 - mean_squared_error: 94.5169 - val_loss: 127.6558 - val_mean_squared_error: 127.6558
# Epoch 178/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 103.2064 - mean_squared_error: 103.2064 - val_loss: 127.6203 - val_mean_squared_error: 127.6203
# Epoch 179/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 107.1789 - mean_squared_error: 107.1789 - val_loss: 127.6072 - val_mean_squared_error: 127.6072
# Epoch 180/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 87.4408 - mean_squared_error: 87.4408 - val_loss: 127.5910 - val_mean_squared_error: 127.5910
# Epoch 181/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94.5126 - mean_squared_error: 94.5126 - val_loss: 127.6111 - val_mean_squared_error: 127.6111
# Epoch 182/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94.3924 - mean_squared_error: 94.3924 - val_loss: 127.6155 - val_mean_squared_error: 127.6155
# Epoch 183/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94.5468 - mean_squared_error: 94.5468 - val_loss: 127.6294 - val_mean_squared_error: 127.6294
# Epoch 184/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.6498 - mean_squared_error: 90.6498 - val_loss: 127.6218 - val_mean_squared_error: 127.6218
# Epoch 185/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.6460 - mean_squared_error: 90.6460 - val_loss: 127.6409 - val_mean_squared_error: 127.6409
# Epoch 186/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.1880 - mean_squared_error: 102.1880 - val_loss: 127.5986 - val_mean_squared_error: 127.5986
# Epoch 187/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.6305 - mean_squared_error: 96.6305 - val_loss: 127.6054 - val_mean_squared_error: 127.6054
# Epoch 188/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 102.7522 - mean_squared_error: 102.7522 - val_loss: 127.6322 - val_mean_squared_error: 127.6322
# Epoch 189/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 94.9082 - mean_squared_error: 94.9082 - val_loss: 127.5852 - val_mean_squared_error: 127.5852
# Epoch 190/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 104.1443 - mean_squared_error: 104.1443 - val_loss: 127.5917 - val_mean_squared_error: 127.5917
# Epoch 191/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.1439 - mean_squared_error: 93.1439 - val_loss: 127.5935 - val_mean_squared_error: 127.5935
# Epoch 192/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.1406 - mean_squared_error: 91.1406 - val_loss: 127.5904 - val_mean_squared_error: 127.5904
# Epoch 193/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.7818 - mean_squared_error: 92.7818 - val_loss: 127.5990 - val_mean_squared_error: 127.5990
# Epoch 194/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.7853 - mean_squared_error: 90.7853 - val_loss: 127.5887 - val_mean_squared_error: 127.5887
# Epoch 195/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.0799 - mean_squared_error: 98.0799 - val_loss: 127.5770 - val_mean_squared_error: 127.5770
# Epoch 196/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 104.3364 - mean_squared_error: 104.3364 - val_loss: 127.5944 - val_mean_squared_error: 127.5944
# Epoch 197/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 103.5379 - mean_squared_error: 103.5379 - val_loss: 127.5854 - val_mean_squared_error: 127.5854
# Epoch 198/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.0806 - mean_squared_error: 101.0806 - val_loss: 127.5872 - val_mean_squared_error: 127.5872
# Epoch 199/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.6399 - mean_squared_error: 98.6399 - val_loss: 127.5922 - val_mean_squared_error: 127.5922
# Epoch 200/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94.0203 - mean_squared_error: 94.0203 - val_loss: 127.5934 - val_mean_squared_error: 127.5934
# Epoch 201/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 105.4470 - mean_squared_error: 105.4470 - val_loss: 127.6105 - val_mean_squared_error: 127.6105
# Epoch 202/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.7982 - mean_squared_error: 95.7982 - val_loss: 127.5872 - val_mean_squared_error: 127.5872
# Epoch 203/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.7709 - mean_squared_error: 97.7709 - val_loss: 127.5844 - val_mean_squared_error: 127.5844
# Epoch 204/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.7849 - mean_squared_error: 92.7849 - val_loss: 127.5862 - val_mean_squared_error: 127.5862
# Epoch 205/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 104.4264 - mean_squared_error: 104.4264 - val_loss: 127.5934 - val_mean_squared_error: 127.5934
# Epoch 206/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 103.0813 - mean_squared_error: 103.0813 - val_loss: 127.5879 - val_mean_squared_error: 127.5879
# Epoch 207/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 89.5264 - mean_squared_error: 89.5264 - val_loss: 127.5760 - val_mean_squared_error: 127.5760
# Epoch 208/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94.1118 - mean_squared_error: 94.1118 - val_loss: 127.5795 - val_mean_squared_error: 127.5795
# Epoch 209/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.7773 - mean_squared_error: 101.7773 - val_loss: 127.5898 - val_mean_squared_error: 127.5898
# Epoch 210/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.2560 - mean_squared_error: 96.2560 - val_loss: 127.5671 - val_mean_squared_error: 127.5671
# Epoch 211/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.8219 - mean_squared_error: 93.8219 - val_loss: 127.5838 - val_mean_squared_error: 127.5838
# Epoch 212/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 106.1075 - mean_squared_error: 106.1075 - val_loss: 127.5934 - val_mean_squared_error: 127.5934
# Epoch 213/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.5625 - mean_squared_error: 95.5625 - val_loss: 127.5785 - val_mean_squared_error: 127.5785
# Epoch 214/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.9199 - mean_squared_error: 90.9199 - val_loss: 127.5807 - val_mean_squared_error: 127.5807
# Epoch 215/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 87.8697 - mean_squared_error: 87.8697 - val_loss: 127.5768 - val_mean_squared_error: 127.5768
# Epoch 216/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.0043 - mean_squared_error: 93.0043 - val_loss: 127.5829 - val_mean_squared_error: 127.5829
# Epoch 217/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.0439 - mean_squared_error: 100.0439 - val_loss: 127.5732 - val_mean_squared_error: 127.5732
# Epoch 218/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.2429 - mean_squared_error: 98.2429 - val_loss: 127.5767 - val_mean_squared_error: 127.5767
# Epoch 219/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.7794 - mean_squared_error: 96.7794 - val_loss: 127.5689 - val_mean_squared_error: 127.5689
# Epoch 220/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.3531 - mean_squared_error: 93.3531 - val_loss: 127.5704 - val_mean_squared_error: 127.5704
# Epoch 221/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.2270 - mean_squared_error: 101.2270 - val_loss: 127.5734 - val_mean_squared_error: 127.5734
# Epoch 222/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 99.9754 - mean_squared_error: 99.9754 - val_loss: 127.5671 - val_mean_squared_error: 127.5671
# Epoch 223/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.8136 - mean_squared_error: 100.8136 - val_loss: 127.5729 - val_mean_squared_error: 127.5729
# Epoch 224/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.0338 - mean_squared_error: 91.0338 - val_loss: 127.5641 - val_mean_squared_error: 127.5641
# Epoch 225/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 97.5595 - mean_squared_error: 97.5595 - val_loss: 127.5609 - val_mean_squared_error: 127.5609
# Epoch 226/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 100.3561 - mean_squared_error: 100.3561 - val_loss: 127.5668 - val_mean_squared_error: 127.5668
# Epoch 227/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.4949 - mean_squared_error: 97.4949 - val_loss: 127.5676 - val_mean_squared_error: 127.5676
# Epoch 228/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 99.3100 - mean_squared_error: 99.3100 - val_loss: 127.5681 - val_mean_squared_error: 127.5681
# Epoch 229/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 88.7488 - mean_squared_error: 88.7488 - val_loss: 127.5627 - val_mean_squared_error: 127.5627
# Epoch 230/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.9291 - mean_squared_error: 98.9291 - val_loss: 127.5628 - val_mean_squared_error: 127.5628
# Epoch 231/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 88.8203 - mean_squared_error: 88.8203 - val_loss: 127.5679 - val_mean_squared_error: 127.5679
# Epoch 232/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 99.7885 - mean_squared_error: 99.7885 - val_loss: 127.5626 - val_mean_squared_error: 127.5626
# Epoch 233/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.5974 - mean_squared_error: 95.5974 - val_loss: 127.5575 - val_mean_squared_error: 127.5575
# Epoch 234/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.4615 - mean_squared_error: 97.4615 - val_loss: 127.5613 - val_mean_squared_error: 127.5613
# Epoch 235/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.0370 - mean_squared_error: 91.0370 - val_loss: 127.5646 - val_mean_squared_error: 127.5646
# Epoch 236/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.7019 - mean_squared_error: 100.7019 - val_loss: 127.5593 - val_mean_squared_error: 127.5593
# Epoch 237/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 104.5301 - mean_squared_error: 104.5301 - val_loss: 127.5634 - val_mean_squared_error: 127.5634
# Epoch 238/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 104.1804 - mean_squared_error: 104.1804 - val_loss: 127.5604 - val_mean_squared_error: 127.5604
# Epoch 239/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.0932 - mean_squared_error: 93.0932 - val_loss: 127.5639 - val_mean_squared_error: 127.5639
# Epoch 240/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.3108 - mean_squared_error: 91.3108 - val_loss: 127.5588 - val_mean_squared_error: 127.5588
# Epoch 241/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.5757 - mean_squared_error: 98.5757 - val_loss: 127.5593 - val_mean_squared_error: 127.5593
# Epoch 242/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.3033 - mean_squared_error: 96.3033 - val_loss: 127.5580 - val_mean_squared_error: 127.5580
# Epoch 243/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.6362 - mean_squared_error: 91.6362 - val_loss: 127.5590 - val_mean_squared_error: 127.5590
# Epoch 244/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 91.8563 - mean_squared_error: 91.8563 - val_loss: 127.5569 - val_mean_squared_error: 127.5569
# Epoch 245/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.8352 - mean_squared_error: 93.8352 - val_loss: 127.5574 - val_mean_squared_error: 127.5574
# Epoch 246/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.0159 - mean_squared_error: 95.0159 - val_loss: 127.5574 - val_mean_squared_error: 127.5574
# Epoch 247/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 110.2628 - mean_squared_error: 110.2628 - val_loss: 127.5592 - val_mean_squared_error: 127.5592
# Epoch 248/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 102.9037 - mean_squared_error: 102.9037 - val_loss: 127.5561 - val_mean_squared_error: 127.5561
# Epoch 249/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.8744 - mean_squared_error: 90.8744 - val_loss: 127.5558 - val_mean_squared_error: 127.5558
# Epoch 250/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 103.6498 - mean_squared_error: 103.6498 - val_loss: 127.5583 - val_mean_squared_error: 127.5583
# Epoch 251/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 83.5783 - mean_squared_error: 83.5783 - val_loss: 127.5554 - val_mean_squared_error: 127.5554
# Epoch 252/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.5140 - mean_squared_error: 97.5140 - val_loss: 127.5565 - val_mean_squared_error: 127.5565
# Epoch 253/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.2065 - mean_squared_error: 95.2065 - val_loss: 127.5552 - val_mean_squared_error: 127.5552
# Epoch 254/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 99.5835 - mean_squared_error: 99.5835 - val_loss: 127.5563 - val_mean_squared_error: 127.5563
# Epoch 255/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 97.7209 - mean_squared_error: 97.7209 - val_loss: 127.5565 - val_mean_squared_error: 127.5565
# Epoch 256/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.6582 - mean_squared_error: 96.6582 - val_loss: 127.5550 - val_mean_squared_error: 127.5550
# Epoch 257/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.8784 - mean_squared_error: 97.8784 - val_loss: 127.5545 - val_mean_squared_error: 127.5545
# Epoch 258/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.9415 - mean_squared_error: 98.9415 - val_loss: 127.5544 - val_mean_squared_error: 127.5544
# Epoch 259/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 104.0356 - mean_squared_error: 104.0356 - val_loss: 127.5529 - val_mean_squared_error: 127.5529
# Epoch 260/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.6393 - mean_squared_error: 90.6393 - val_loss: 127.5545 - val_mean_squared_error: 127.5545
# Epoch 261/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.5697 - mean_squared_error: 101.5697 - val_loss: 127.5538 - val_mean_squared_error: 127.5538
# Epoch 262/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 96.1652 - mean_squared_error: 96.1652 - val_loss: 127.5537 - val_mean_squared_error: 127.5537
# Epoch 263/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 100.4611 - mean_squared_error: 100.4611 - val_loss: 127.5535 - val_mean_squared_error: 127.5535
# Epoch 264/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.0798 - mean_squared_error: 93.0798 - val_loss: 127.5541 - val_mean_squared_error: 127.5541
# Epoch 265/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 89.1753 - mean_squared_error: 89.1753 - val_loss: 127.5548 - val_mean_squared_error: 127.5548
# Epoch 266/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 106.5103 - mean_squared_error: 106.5103 - val_loss: 127.5540 - val_mean_squared_error: 127.5540
# Epoch 267/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.0919 - mean_squared_error: 91.0919 - val_loss: 127.5531 - val_mean_squared_error: 127.5531
# Epoch 268/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.4415 - mean_squared_error: 92.4415 - val_loss: 127.5534 - val_mean_squared_error: 127.5534
# Epoch 269/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.2649 - mean_squared_error: 92.2649 - val_loss: 127.5543 - val_mean_squared_error: 127.5543
# Epoch 270/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.1326 - mean_squared_error: 101.1326 - val_loss: 127.5533 - val_mean_squared_error: 127.5533
# Epoch 271/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 89.3577 - mean_squared_error: 89.3577 - val_loss: 127.5528 - val_mean_squared_error: 127.5528
# Epoch 272/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.9597 - mean_squared_error: 95.9597 - val_loss: 127.5523 - val_mean_squared_error: 127.5523
# Epoch 273/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.7878 - mean_squared_error: 96.7878 - val_loss: 127.5519 - val_mean_squared_error: 127.5519
# Epoch 274/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.4228 - mean_squared_error: 98.4228 - val_loss: 127.5523 - val_mean_squared_error: 127.5523
# Epoch 275/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.0685 - mean_squared_error: 90.0685 - val_loss: 127.5510 - val_mean_squared_error: 127.5510
# Epoch 276/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.7054 - mean_squared_error: 91.7054 - val_loss: 127.5524 - val_mean_squared_error: 127.5524
# Epoch 277/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 92.0299 - mean_squared_error: 92.0299 - val_loss: 127.5504 - val_mean_squared_error: 127.5504
# Epoch 278/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 90.6222 - mean_squared_error: 90.6222 - val_loss: 127.5515 - val_mean_squared_error: 127.5515
# Epoch 279/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 83.8913 - mean_squared_error: 83.8913 - val_loss: 127.5520 - val_mean_squared_error: 127.5520
# Epoch 280/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 95.0228 - mean_squared_error: 95.0228 - val_loss: 127.5517 - val_mean_squared_error: 127.5517
# Epoch 281/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 107.2005 - mean_squared_error: 107.2005 - val_loss: 127.5521 - val_mean_squared_error: 127.5521
# Epoch 282/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.0887 - mean_squared_error: 95.0887 - val_loss: 127.5515 - val_mean_squared_error: 127.5515
# Epoch 283/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 101.0107 - mean_squared_error: 101.0107 - val_loss: 127.5514 - val_mean_squared_error: 127.5514
# Epoch 284/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.4058 - mean_squared_error: 98.4058 - val_loss: 127.5502 - val_mean_squared_error: 127.5502
# Epoch 285/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.5704 - mean_squared_error: 93.5704 - val_loss: 127.5510 - val_mean_squared_error: 127.5510
# Epoch 286/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.7203 - mean_squared_error: 96.7203 - val_loss: 127.5517 - val_mean_squared_error: 127.5517
# Epoch 287/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91.1394 - mean_squared_error: 91.1394 - val_loss: 127.5508 - val_mean_squared_error: 127.5508
# Epoch 288/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 96.4551 - mean_squared_error: 96.4551 - val_loss: 127.5508 - val_mean_squared_error: 127.5508
# Epoch 289/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 89.3689 - mean_squared_error: 89.3689 - val_loss: 127.5513 - val_mean_squared_error: 127.5513
# Epoch 290/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 95.5256 - mean_squared_error: 95.5256 - val_loss: 127.5513 - val_mean_squared_error: 127.5513
# Epoch 291/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 97.9440 - mean_squared_error: 97.9440 - val_loss: 127.5504 - val_mean_squared_error: 127.5504
# Epoch 292/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.2124 - mean_squared_error: 93.2124 - val_loss: 127.5506 - val_mean_squared_error: 127.5506
# Epoch 293/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 105.1969 - mean_squared_error: 105.1969 - val_loss: 127.5500 - val_mean_squared_error: 127.5500
# Epoch 294/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 103.7725 - mean_squared_error: 103.7725 - val_loss: 127.5502 - val_mean_squared_error: 127.5502
# Epoch 295/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 88.0086 - mean_squared_error: 88.0086 - val_loss: 127.5504 - val_mean_squared_error: 127.5504
# Epoch 296/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 99.4511 - mean_squared_error: 99.4511 - val_loss: 127.5501 - val_mean_squared_error: 127.5501
# Epoch 297/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 95.5253 - mean_squared_error: 95.5253 - val_loss: 127.5498 - val_mean_squared_error: 127.5498
# Epoch 298/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 105.4923 - mean_squared_error: 105.4923 - val_loss: 127.5506 - val_mean_squared_error: 127.5506
# Epoch 299/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 93.0497 - mean_squared_error: 93.0497 - val_loss: 127.5499 - val_mean_squared_error: 127.5499
# Epoch 300/300
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 98.5995 - mean_squared_error: 98.5995 - val_loss: 127.5499 - val_mean_squared_error: 127.5499
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Mean Absolute Error on Test Data: 133.96466064453125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Train RMSE:  10.102903758925693
# Test RMSE:  11.5743084716797

# %% [markdown]
# ##Final Submission:

# %%
submission_dfs['Timestamp'] = submission_dfs['Timestamp'].astype(str).str[:13]

# %%
ansy = model.predict(dfs) #Remember to train on 100% data before submission
ansy = ansy[:,0] #only for neural network, else comment it
ide = []
ansye = []
for i in range(len(ansy)+1):
  if(i == 0):
    ide.append("Timestamp")
    ansye.append("Water_Consumption")
  else:
    ide.append(submission_dfs['Timestamp'].iloc[i-1])
    ansye.append(ansy[i-1])

np.savetxt("Pred.csv", list(zip(ide, ansye)), delimiter=",", fmt='%s')
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
